# %% [markdown]
# ## Step 1 - Add your OpenAI API key.
# The key must be taken from a registered OpenAI account.
# Link to the keys sub-menu https://platform.openai.com/account/api-keys.

# %%
# %env OPENAI_API_KEY YOUT_OPENAI_API_KEY
# Out:
# env: OPENAI_API_KEY=YOUT_OPENAI_API_KEY

# %% [markdown]
# ## Step 2 - Installing necessary libraries
# The libraries below are needed for:
# - Loading of text data from files and further preparation;
# - Creating embeddings via Langchain;
# - Prompting;

# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in ./venv/lib/python3.9/site-packages (0.0.142)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in ./venv/lib/python3.9/site-packages (from langchain) (1.2.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in ./venv/lib/python3.9/site-packages (from langchain) (8.2.2)
# Requirement already satisfied: gptcache>=0.1.7 in ./venv/lib/python3.9/site-packages (from langchain) (0.1.13)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in ./venv/lib/python3.9/site-packages (from langchain) (0.5.7)
# Requirement already satisfied: SQLAlchemy<2,>=1 in ./venv/lib/python3.9/site-packages (from langchain) (1.4.47)
# Requirement already satisfied: numpy<2,>=1 in ./venv/lib/python3.9/site-packages (from langchain) (1.24.2)
# Requirement already satisfied: PyYAML>=5.4.1 in ./venv/lib/python3.9/site-packages (from langchain) (6.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./venv/lib/python3.9/site-packages (from langchain) (3.8.4)
# Requirement already satisfied: pydantic<2,>=1 in ./venv/lib/python3.9/site-packages (from langchain) (1.10.7)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in ./venv/lib/python3.9/site-packages (from langchain) (2.8.4)
# Requirement already satisfied: requests<3,>=2 in ./venv/lib/python3.9/site-packages (from langchain) (2.28.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in ./venv/lib/python3.9/site-packages (from langchain) (4.0.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.8.2)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in ./venv/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (0.8.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in ./venv/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (1.5.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in ./venv/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (3.19.0)
# Requirement already satisfied: openai in ./venv/lib/python3.9/site-packages (from gptcache>=0.1.7->langchain) (0.27.4)
# Requirement already satisfied: cachetools in ./venv/lib/python3.9/site-packages (from gptcache>=0.1.7->langchain) (5.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in ./venv/lib/python3.9/site-packages (from pydantic<2,>=1->langchain) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (1.26.15)
# Requirement already satisfied: packaging>=17.0 in ./venv/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (23.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./venv/lib/python3.9/site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: tqdm in ./venv/lib/python3.9/site-packages (from openai->gptcache>=0.1.7->langchain) (4.65.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Step 3 - Libraries import
# Imported libraries will be used across the whole notebook

# %%
from langchain.embeddings import OpenAIEmbeddings
from langchain.document_loaders import TextLoader, PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter

# %% [markdown]
# ## Step 4 - Create tool for embedding generation
# The tool is provided by Langchain and simplified embeddings generation process while providing reasonable defaults.
#
# By default, OpenAIEmbeddings uses nearly optimal settings:
# Model: text-embedding-ada-002
# Max chunk length: 8191

# %%
embeddings = OpenAIEmbeddings()

# %%
query = "What am I doing here?"
query_embedding = embeddings.embed_query(query)

query_embedding
# Out:
# [-0.009089913617436905,
#  -0.0317989494628773,
#  0.01587427686933764,
#  -0.016390821866538088,
#  -0.03472183068608283,
#  0.004176446923055135,
#  -0.00835289384611027,
#  0.01373250981349047,
#  0.017108944172611485,
#  -0.016542005313854063,
#  0.023521647340425018,
#  -0.018809758886238717,
#  -0.0026441380227851703,
#  0.0115403479647638,
#  -0.0005110320335433305,
#  -0.003703997951700825,
#  0.03404150703580599,
#  -0.014740400083145313,
#  -0.0047811811779802935,
#  -0.0122080754779577,
#  -0.02120349804383834,
#  -0.015256944149023238,
#  0.017436507066699403,
#  -0.002888236491122946,
#  0.008390689707939264,
#  0.01700815458685249,
#  0.009864729250592535,
#  -0.02522246205405225,
#  0.0069607445613177185,
#  -0.01867117436997325,
#  0.017020753517902994,
#  0.007559179816378884,
#  -0.015080563770928776,
#  -0.01797824806335582,
#  -0.02000662939636105,
#  0.0009165505224679578,
#  0.018557785853163748,
#  -0.005496153751291066,
#  0.019527881192312118,
#  -0.011786020600990998,
#  0.01057025262561543,
#  -0.0023512198607798396,
#  -0.017285323619383428,
#  -0.005505602483917684,
#  -0.019175118573478152,
#  0.008837940584361935,
#  -0.005304024243722212,
#  -0.02600357715273313,
#  0.0016016011584026996,
#  0.0021638151851855547,
#  0.023798818235600996,
#  -0.004233140715798626,
#  -0.04250778753608072,
#  -0.020901131149206394,
#  -0.010255286799932976,
#  0.005398514363955956,
#  0.004110303932023766,
#  0.03900536666042222,
#  -0.0024913797090878828,
#  0.005515051682205563,
#  -0.011363966655346815,
#  0.02408858619918244,
#  0.00203310430233476,
#  -0.014664808359487325,
#  0.007710363263694859,
#  -0.009442675304948352,
#  0.003996916346536785,
#  0.0002716580188303504,
#  -0.00829619958770552,
#  -0.009404879443119359,
#  0.0046110997997498215,
#  0.008693056602571213,
#  -0.01668058983011953,
#  -0.0030724916667852348,
#  0.0176506851692679,
#  -0.023408258823615517,
#  -0.013631720227731473,
#  -0.0011126167885364923,
#  0.026759496251958045,
#  -0.0006822946779751015,
#  0.011830115928345243,
#  -0.028624093343951756,
#  -0.01534513480373173,
#  0.027540611350638924,
#  0.011275776000638324,
#  0.006519792684759039,
#  0.01603805924770412,
#  0.022375172554504705,
#  -0.004422120024943594,
#  -0.018734167162580733,
#  -0.0038362837009329326,
#  0.011565544895542288,
#  0.02466812212634533,
#  0.02344605561676703,
#  0.0062804185827345736,
#  0.025512231880278735,
#  -0.004768582712591048,
#  0.03363834869277,
#  0.017524697721407894,
#  -0.019212915366629665,
#  -0.001729162308490868,
#  0.005634738733217796,
#  -0.013593924365902479,
#  -0.00424573918118787,
#  -0.009782838061409296,
#  -0.003326039100580259,
#  -0.02796896569313088,
#  -0.002749651509196216,
#  0.023307471100501558,
#  -0.011786020600990998,
#  -0.022828722896452627,
#  -0.0006378058086484999,
#  0.018381404543746763,
#  -0.026129564600593135,
#  -0.0023653931925503974,
#  -0.016718386623271044,
#  0.014085271501001917,
#  0.03152178043034636,
#  -0.04475034510900941,
#  -0.02083813835659891,
#  0.023244478307894077,
#  0.019880641948501046,
#  0.0059812009552039904,
#  0.014916781392562296,
#  0.03227769766692623,
#  -0.0070741321468047,
#  -0.02582719770596119,
#  -0.015748291284122674,
#  -0.011143490949898105,
#  -0.004270936577627619,
#  0.008686757137045961,
#  0.02211060059037923,
#  0.005086697805374868,
#  0.00860486594786272,
#  -0.00713082593954819,
#  0.00037185653493126557,
#  -0.010066307490788007,
#  0.012523041303640153,
#  -0.010828525124215652,
#  -0.027087061008691002,
#  0.0010063157525194751,
#  0.029430406304733647,
#  0.01637822293548758,
#  -0.019112125780870667,
#  -0.008888335377241433,
#  0.005417412294870453,
#  0.009159205875569641,
#  -0.020031825395817018,
#  -0.008510376758951497,
#  -0.02388700702766445,
#  -0.0010448991639544403,
#  0.016831773277435506,
#  -0.000191243310535335,
#  0.007055234215890203,
#  0.017990846994406322,
#  0.006195377660788708,
#  -0.02880047465336874,
#  0.02610436673849213,
#  0.0024583082135721983,
#  -0.00999071576713002,
#  -0.016025460316653615,
#  0.029153235409557665,
#  0.0004614249357889475,
#  -0.011414361448226313,
#  0.030614677883805473,
#  0.015030168978049277,
#  0.030513888298046476,
#  -0.007949737365719325,
#  -0.01820502509697482,
#  -0.007156023335987939,
#  -0.005055201409071126,
#  0.029405208442632638,
#  -0.02536104843296276,
#  0.017764071823432363,
#  -0.012661625819905624,
#  0.007830050314707092,
#  -0.006538690615673536,
#  -0.01809163658016532,
#  -0.009669450475922315,
#  -0.014589216635829337,
#  -0.03137059698303039,
#  -0.0031150118949275375,
#  0.017285323619383428,
#  0.03396591344950296,
#  -0.009127709479265899,
#  0.0033008417041405095,
#  -0.0017811317349210494,
#  -0.01382070046819896,
#  0.001518135219253462,
#  -0.017222330826775947,
#  -0.005511901949442936,
#  0.02610436673849213,
#  -0.02686028583771704,
#  -0.00043347169780487307,
#  -0.6728677951061247,
#  -0.022362573623454198,
#  0.04127312209545191,
#  -0.007596975678207878,
#  -0.002700831815528661,
#  0.0074331932998413985,
#  0.004863072367163533,
#  0.019137323642971677,
#  -0.021178302044382372,
#  0.03265565442257113,
#  0.006721370459293253,
#  0.008882035911716182,
#  0.0078048529182673425,
#  0.0017842813512683605,
#  0.0036032090644337184,
#  -0.020246003498385515,
#  0.010337177989116215,
#  -0.004532358343329208,
#  -0.00600639835164374,
#  -0.008422186104243005,
#  -0.004104004466498514,
#  0.025902789429619176,
#  -0.00027894160122095084,
#  -0.004277236043152871,
#  0.01723492975782645,
#  0.009656852476194331,
#  -0.0003531554332106041,
#  -0.012371857856324178,
#  -0.00796233629676983,
#  0.021480668939014323,
#  -0.009814335389035558,
#  0.005080398805510876,
#  0.00713082593954819,
#  0.008598566482337469,
#  0.07019958233403562,
#  -0.015773489146223684,
#  0.005200085856523109,
#  0.031093426087854405,
#  -0.014652210359759341,
#  0.014576617704778833,
#  -0.013896292191856948,
#  -0.016277433349728587,
#  0.012233272408736189,
#  -0.014564019705050849,
#  0.006500894288183283,
#  -0.008611165413387974,
#  0.016252235487627577,
#  -0.01204429309959122,
#  0.026507523218883073,
#  0.00017647928745647,
#  -0.007187520197952941,
#  -0.00414809979385276,
#  0.0004464640544124184,
#  0.01442543425746286,
#  -0.003568562702536721,
#  -0.020686954909282934,
#  0.013215965747612543,
#  0.008346594380585017,
#  0.023748422511398977,
#  0.01009780388709175,
#  -0.01395928498446443,
#  0.0296319836136066,
#  -0.019578275053869096,
#  -0.0015252220015540558,
#  -0.0175372966524584,
#  0.01173562673943402,
#  -0.036813204811695546,
#  0.02522246205405225,
#  0.006025296282558237,
#  -0.01726012761992746,
#  0.030891846916336414,
#  0.007187520197952941,
#  -0.03174855373867528,
#  0.02605397287693515,
#  0.012674224750956128,
#  0.02238776962291017,
#  0.006519792684759039,
#  -0.007653669470951368,
#  0.0195908739849196,
#  -0.00962535514856807,
#  0.0011480504672088312,
#  -0.007918240969415584,
#  -0.02311849086003407,
#  -0.00793713843466882,
#  0.015118359632757768,
#  -0.010551355160362192,
#  -0.03074066346902044,
#  0.008541873155255238,
#  0.012415952252355904,
#  0.0032787942732940166,
#  0.01984284701799457,
#  0.0243027624391059,
#  -0.016504208520702546,
#  -0.030413098712287482,
#  -0.0012590758695391576,
#  0.0038079368045611873,
#  -0.008932430704595679,
#  -0.010608048487444423,
#  0.004270936577627619,
#  0.008195410933269044,
#  -0.0007240277057573778,
#  -0.012649026888855119,
#  0.01903653405721268,
#  -0.002052002233249257,
#  0.024227170715447912,
#  0.009234797599227629,
#  -0.01647901252124658,
#  0.028372120310876783,
#  0.006941846630403222,
#  -0.005511901949442936,
#  -0.0024677571790294468,
#  -0.007760757590913097,
#  -0.00025571287506932934,
#  0.008686757137045961,
#  0.0008133992192135669,
#  -0.029203631133759685,
#  0.009442675304948352,
#  0.00721271712873143,
#  0.012031694168540717,
#  -0.007943437900194073,
#  0.009530865959656845,
#  0.011332470259043074,
#  0.016277433349728587,
#  -0.006595384408417027,
#  0.006544989615537529,
#  0.019074330850364193,
#  0.0006752079538821652,
#  0.0154837193199972,
#  -0.03187453932389025,
#  -0.016416017865994056,
#  0.006967044026842971,
#  -0.004639446463290937,
#  0.016189242695020093,
#  -0.005455208156699446,
#  0.007533982419939135,
#  0.017764071823432363,
#  -0.005978051222441365,
#  0.022576749863377658,
#  0.014538821842949839,
#  0.004211093052121502,
#  -0.02189642435045577,
#  -0.017990846994406322,
#  -0.00995921937082628,
#  0.0013330928432311467,
#  -0.008069424416731558,
#  -0.02263974265598514,
#  0.015307338941902737,
#  -0.008567070086033728,
#  0.00026378386154675757,
#  0.006677275597600266,
#  0.011193884811455085,
#  -0.006113486471605468,
#  -0.050822884589039476,
#  0.013530931573294996,
#  -0.001444118245561473,
#  -0.015798685145679652,
#  0.0235846401330325,
#  -0.014614413566607826,
#  -0.011981299375661218,
#  -0.026482325356782063,
#  0.0022756281371218525,
#  0.027213046593905967,
#  -0.022022409935670735,
#  -0.02450434161062389,
#  -0.007282009852525424,
#  -0.01254193876889339,
#  -0.003234698945939771,
#  0.01085372205499414,
#  -0.006182779195399463,
#  -0.017864861409191357,
#  -0.005108745469051991,
#  0.0018787711222561596,
#  -0.011748224739162004,
#  -0.0041386510612261415,
#  -0.017373514274091922,
#  0.005565446009423801,
#  -0.0073261051798796705,
#  -0.013064782300296568,
#  -0.023257075376299542,
#  -0.016554604244904566,
#  -0.005052051676308501,
#  0.017990846994406322,
#  0.012063190564844457,
#  0.033890323588490014,
#  0.01845699626740475,
#  -0.001481126790615125,
#  0.009360784115765113,
#  0.010576552091140681,
#  -0.0028394167974553908,
#  0.016491609589652043,
#  -0.0032819437732260126,
#  0.012397054787102667,
#  -0.000432290577122717,
#  0.027187848731804957,
#  0.005420561561971819,
#  -0.018545186922113245,
#  0.023105891928983567,
#  0.021102710320724385,
#  -0.009871028716117787,
#  0.015408127596339213,
#  0.015609705836534685,
#  0.019124724711921174,
#  0.005987500420729243,
#  0.000611427378838081,
#  -0.014123067362830909,
#  -0.03938332714135719,
#  -0.016101052040311602,
#  -0.015408127596339213,
#  -0.005823718042362764,
#  0.01301438750741707,
#  0.010834824589740905,
#  -0.010393872247520966,
#  0.007294608317914669,
#  -0.008900934308291938,
#  0.009316688788410868,
#  0.026230354186352133,
#  -0.011886810186749993,
#  0.013593924365902479,
#  -0.013896292191856948,
#  0.0064001056337468065,
#  0.009871028716117787,
#  0.01442543425746286,
#  -0.016831773277435506,
#  -0.0194774854681101,
#  0.002842566530218017,
#  0.02531065270876074,
#  0.0030079235421351792,
#  0.03270605014677315,
#  0.004812677574284035,
#  -0.019666465708577587,
#  -0.032479276838444225,
#  -0.009619055683042816,
#  0.00880014472253294,
#  0.02536104843296276,
#  -0.022425566416061683,
#  -0.010286784127559238,
#  0.00040984928416175207,
#  0.00448196355044971,
#  -0.0014149839159990712,
#  -0.014085271501001917,
#  -0.016113650971362106,
#  0.014173462155710408,
#  0.0262555501858081,
#  -0.0056725345950467895,
#  0.04956302128630966,
#  0.004292984241304742,
#  0.027767386521612886,
#  0.006526091684623032,
#  0.001822077213097354,
#  0.024441346955371368,
#  -0.03356275883175706,
#  0.0023701177916943365,
#  -0.022349974692403695,
#  -0.006614282339331524,
#  -0.007754458591049104,
#  -0.024038190474980424,
#  0.006349710840867309,
#  -0.0050709496072229975,
#  0.029984746232440566,
#  0.011754524204687256,
#  0.01562230476758519,
#  -0.003452025384287114,
#  0.029455604166834657,
#  -0.016252235487627577,
#  0.010998606036784864,
#  -0.010551355160362192,
#  -0.02311849086003407,
#  -0.034192690483121964,
#  0.013329353333099524,
#  -0.0012134057922189136,
#  -0.0012086813094902894,
#  -0.006677275597600266,
#  0.006973343026706963,
#  -0.009442675304948352,
#  0.025650816396544204,
#  0.02120349804383834,
#  0.016063257109805128,
#  -0.0044095215595543495,
#  0.015080563770928776,
#  0.008926131239070427,
#  -0.007527682954413883,
#  -0.024642926126889363,
#  0.020913730080256897,
#  -0.0003706753851452808,
#  0.0014504175946714103,
#  0.006296166780886444,
#  -0.012743517009088863,
#  -0.0002502009591500486,
#  0.00033445433148994273,
#  0.01581128407673016,
#  0.002582719630897741,
#  0.023257075376299542,
#  -0.014475829050342356,
#  -0.002845716262980643,
#  0.008308798518756025,
#  0.006343411375342056,
#  0.045682643655006266,
#  0.012529339837842886,
#  0.018519990922657274,
#  -0.001596089242483419,
#  0.00317800515319628,
#  -0.009140308410316404,
#  0.008264703191401778,
#  -0.014450632119563867,
#  0.017108944172611485,
#  0.0049701604871252615,
#  0.026986271422932005,
#  -0.029505998028391635,
#  0.001911842501356529,
#  -0.025474435087127222,
#  7.918437303844331e-05,
#  0.011704129411807759,
#  0.006481996357268786,
#  -0.020598764254574443,
#  -0.016025460316653615,
#  -0.0015701046456836434,
#  -0.017310521481484438,
#  0.006311914979038315,
#  0.030614677883805473,
#  -0.00721271712873143,
#  -0.017890059271292367,
#  -0.0326304602857602,
#  -0.018545186922113245,
#  -0.011357667189821563,
#  0.08395728721565954,
#  0.02333266709995753,
#  -0.005659935663996285,
#  0.007628472074511619,
#  -0.019175118573478152,
#  -0.0028110699010836454,
#  -0.010702538607678167,
#  -0.0303627048507305,
#  0.014828590737853803,
#  0.007748159125523853,
#  -0.013417543987808015,
#  -0.009096213082962159,
#  -0.007256812456085675,
#  0.020913730080256897,
#  0.0010685215775975614,
#  -0.0038488823991528072,
#  0.016000264317197647,
#  -0.005404813363819948,
#  -0.01756249451455941,
#  -0.025096476468837284,
#  -0.006633180270246021,
#  0.008516676224476749,
#  0.022400368553960673,
#  -0.0017638085539725507,
#  -0.0033228893678176326,
#  0.02311849086003407,
#  -0.005943405093374997,
#  -0.01193090551410424,
#  0.009259995461328637,
#  -0.01739871213619293,
#  -0.008396989173464516,
#  0.013455339849637009,
#  -0.013619122228003488,
#  -0.0004614249357889475,
#  -0.01772627689292589,
#  0.012226972943210936,
#  -0.015584508905756196,
#  0.018041242718608342,
#  -0.004220541784748121,
#  -0.00395282101918254,
#  0.00428668477577949,
#  0.007055234215890203,
#  -0.008107220278560551,
#  0.00043898361372415385,
#  0.018910548471997714,
#  -0.02247596027761866,
#  -0.0244161509559154,
#  0.017197132964674938,
#  0.02408858619918244,
#  -0.008642661809691714,
#  0.018318411751139282,
#  0.007105629008769701,
#  -0.005367017501990954,
#  -0.01864597650787224,
#  0.017247528688876957,
#  0.01617664376396959,
#  0.0005157565162719546,
#  -0.013039585369518079,
#  -0.010469463971178953,
#  -0.016907365001093494,
#  -0.023105891928983567,
#  -0.0154837193199972,
#  0.006475697357404794,
#  0.0022929512016550365,
#  -0.018494793060556264,
#  -0.03152178043034636,
#  -0.026230354186352133,
#  0.015584508905756196,
#  -0.0025795701309657445,
#  -0.00418904538844438,
#  0.02791856996892886,
#  -0.024466544817472378,
#  -0.02095152687340841,
#  -0.0183688074753413,
#  0.007811152383792595,
#  0.01853258799106274,
#  0.004195344853969632,
#  0.0007531620353197796,
#  -0.019212915366629665,
#  0.014916781392562296,
#  0.013493135711466002,
#  -0.05583713993785772,
#  -0.0014126217328424165,
#  -0.020107417119475005,
#  -0.017915255270748335,
#  0.011886810186749993,
#  0.02028379842889199,
#  0.01315297295500506,
#  -0.013997080846293425,
#  0.027238244456006977,
#  0.005735527387654272,
#  0.02425236857754892,
#  0.03265565442257113,
#  -0.02761620307429691,
#  0.017348316411990913,
#  0.0028898113575042588,
#  -0.00349612071164136,
#  -0.004296133974067368,
#  -0.008693056602571213,
#  0.00041969196621432874,
#  0.00890723377381719,
#  -0.032000528634395294,
#  0.0023260224643400908,
#  -0.0070426357505009585,
#  0.00026673667780406207,
#  0.002634689057327922,
#  0.02360983799513351,
#  0.002452008980877576,
#  -0.017222330826775947,
#  -0.01961607184702061,
#  0.009745042199580303,
#  -0.03202572277120622,
#  0.020989321803914884,
#  -0.0067780642520367425,
#  0.020850737287649416,
#  0.024164177922840428,
#  0.013064782300296568,
#  0.0635978989257546,
#  0.0034646240825069886,
#  0.01356872743512399,
#  0.0010496236466830645,
#  -0.03147138470614434,
#  0.02344605561676703,
#  0.03298321917930409,
#  -0.0009661576493261695,
#  -0.005376466700278832,
#  -0.0051717387273207335,
#  -0.04097075520081996,
#  -0.0023953149553034556,
#  -0.020031825395817018,
#  -0.016995555655801985,
#  0.02372322464929797,
#  -0.005767024249619273,
#  -0.022841321827503133,
#  -0.0189735412646052,
#  -0.011962401910407981,
#  0.0027622502074160903,
#  0.010425368643824708,
#  -0.0028488657629126392,
#  -0.01892314554040318,
#  -0.01290099992193009,
#  0.0016598698175275032,
#  -0.02208540272827822,
#  -0.0023165734988828423,
#  -0.019527881192312118,
#  -0.036687219226480584,
#  0.00519063665823523,
#  0.00829619958770552,
#  0.0003303203945504822,
#  0.012989190576638582,
#  0.0012559262531918463,
#  0.004863072367163533,
#  -0.006047343946235359,
#  -0.005278827312943723,
#  -0.0012756116172969998,
#  -0.029455604166834657,
#  -0.022601947725478664,
#  -0.00738279897262316,
#  0.0317989494628773,
#  0.03426828034413491,
#  0.018381404543746763,
#  0.006708771993904007,
#  0.03252966883735616,
#  0.013404945056757512,
#  -0.017638086238217398,
#  -0.015937269661945124,
#  -0.00995921937082628,
#  0.005653636664132293,
#  -0.014538821842949839,
#  0.02847290989663578,
#  -0.0034110797896954943,
#  0.008592267948134736,
#  0.004570154205158202,
#  0.011729327273908767,
#  -0.01373250981349047,
#  0.012352959459748422,
#  -0.0048284262380971655,
#  -0.0036473041589573344,
#  -0.032857233594089125,
#  -0.01994363660375357,
#  -0.01756249451455941,
#  -5.3248907139576065e-05,
#  0.0015803410443315483,
#  -0.002582719630897741,
#  0.006941846630403222,
#  -0.022715334379643126,
#  0.0021543662197283063,
#  0.016667990899069028,
#  -0.00968204940697282,
#  -0.014614413566607826,
#  0.020271199497841487,
#  -0.026431931495225085,
#  0.019225514297680168,
#  0.000897652591553461,
#  0.032252499804825224,
#  -0.015672699560464687,
#  -0.001048836213492408,
#  -0.00418904538844438,
#  0.007559179816378884,
#  0.0017354616576008054,
#  0.00532922164016196,
#  0.005351269303839084,
#  -0.017335719343585448,
#  0.006456799426490297,
#  0.002291376335273723,
#  0.005937105627849744,
#  -0.010456865040128448,
#  -0.004793779643369538,
#  0.04190305374681682,
#  0.006132384402519965,
#  -0.0045166096795160775,
#  -0.01584908086988167,
#  -0.009291491857632379,
#  -0.04233140622666374,
#  0.023395661755210052,
#  0.0010299382825779111,
#  -0.012510442372589648,
#  0.009140308410316404,
#  0.019779854225387087,
#  -0.020409785876751997,
#  -0.007086731077855204,
#  0.0033984810914756197,
#  0.0209263290113074,
#  0.02194681821201275,
#  0.0063812077028323096,
#  0.019326302020794123,
#  -0.014891583530461286,
#  0.0052536299165039735,
#  0.010123001749192758,
#  0.010104103352617001,
#  -0.008384390242414011,
#  0.03154697829244737,
#  0.00799383269307357,
#  -0.010532456763786436,
#  -0.012195476546907195,
#  -0.012069490030369709,
#  -0.0062520714535321984,
#  0.004494562015838955,
#  -0.017688480099774376,
#  0.012094687892470719,
#  0.037972280391311404,
#  -0.016113650971362106,
#  0.0043811744303519735,
#  -0.005795370913160389,
#  -0.022009811004620232,
#  0.02455473547218087,
#  0.003826834735475684,
#  -0.022236586175594195,
#  -0.0048000791088947895,
#  -0.022211390176138223,
#  -0.023068096998477092,
#  0.008390689707939264,
#  0.0009015896410914287,
#  0.02386181102820848,
#  0.0014724652583485332,
#  -0.01395928498446443,
#  0.0012000197772236974,
#  -0.015307338941902737,
#  0.010110402818142253,
#  0.02711225700814697,
#  0.00782375084918184,
#  0.022261784037695204,
#  -0.009984416301604768,
#  0.005026854279868751,
#  -0.009001722962728415,
#  -0.005587493673100924,
#  -0.028271332587762828,
#  -0.01659239917541104,
#  -0.02120349804383834,
#  0.02277832717225061,
#  0.00517488846008336,
#  0.0016220739556985096,
#  0.0008275726673994395,
#  0.02605397287693515,
#  0.017348316411990913,
#  -0.004075657802957399,
#  -0.0019149922341191552,
#  0.00849147836237574,
#  -0.004711888454186298,
#  -0.014992373116220283,
#  0.010173395610749736,
#  0.003924473889980165,
#  -0.028876066377026728,
#  0.005795370913160389,
#  -0.0317989494628773,
#  -0.008882035911716182,
#  -0.017461704928800413,
#  0.006784363717561995,
#  -0.00904581829008266,
#  -0.020170411774727528,
#  -0.006866254906745235,
#  -0.026406733633124076,
#  0.024869701297863322,
#  0.019742057432235574,
#  -0.017247528688876957,
#  -0.004658344394205434,
#  0.008208008932997028,
#  0.020132614981576015,
#  0.023156287653185587,
#  0.0031795800195775934,
#  -0.005870963102479636,
#  0.0033354880660375072,
#  -0.017776670754482866,
#  0.007533982419939135,
#  -0.0005358355969724362,
#  -0.03149658256824535,
#  0.011830115928345243,
#  -0.009329287719461373,
#  -0.020623962116675453,
#  -0.03066507174536245,
#  0.004815827307046661,
#  0.018444399198999286,
#  -0.014841189668904308,
#  -0.023798818235600996,
#  0.016466413590196075,
#  0.006607982873806271,
#  0.01409787043205242,
#  -0.008585968482609485,
#  -0.02711225700814697,
#  0.0060693911442512224,
#  -0.00898912403167791,
#  0.007357601576183412,
#  -0.0002425236747160343,
#  -0.010652143814798669,
#  0.0035213178752504792,
#  0.012529339837842886,
#  0.02034679122149947,
#  -0.0030441445375828597,
#  0.00015512067147691464,
#  -0.02169484517893778,
#  0.020019228327411556,
#  0.015634902767313174,
#  -0.00815761507144005,
#  -0.03421788834522297,
#  -0.003011073274897805,
#  0.006885152837659731,
#  -0.0023764170243889588,
#  0.0013567152568742676,
#  -0.011464756241105812,
#  0.026129564600593135,
#  -0.022349974692403695,
#  0.009808035923510304,
#  -0.013631720227731473,
#  0.006916649233963472,
#  -0.010639545815070685,
#  0.010563953160090176,
#  -0.0009252121129422071,
#  0.009543463959384829,
#  -0.016504208520702546,
#  -0.011641136619200276,
#  -0.024403552024864893,
#  0.011307273328264585,
#  0.007426893834316147,
#  -0.015559311043655188,
#  -0.008869437911988196,
#  -0.014639611428708836,
#  -0.004491412748737589,
#  -0.04263377312129568,
#  0.020913730080256897,
#  -0.009587559286739076,
#  0.01195610244488273,
#  0.015773489146223684,
#  -0.01065844328032392,
#  0.03210131635750925,
#  -0.0018331010449359156,
#  -0.007811152383792595,
#  -0.008069424416731558,
#  -0.009127709479265899,
#  -0.0008043439703516467,
#  -0.021606654524229288,
#  0.003864630597304678,
#  0.005278827312943723,
#  -0.011653735550250779,
#  0.0006165455781620335,
#  0.007792254452878098,
#  -0.0024409851490390148,
#  0.0032079269159493388,
#  0.008000132158598823,
#  -0.024869701297863322,
#  0.01034977692016672,
#  0.0032252499804825223,
#  -0.0005200872824052506,
#  0.009612757148840084,
#  0.021367280422204822,
#  0.0025984680618802414,
#  -0.018746766093631236,
#  -0.015282142011124248,
#  0.0033921818587809975,
#  0.024794109574205334,
#  0.007250512990560423,
#  -0.007351302110658159,
#  0.011880510721224742,
#  -0.028346924311420815,
#  0.001528371617901367,
#  0.0084095871731925,
#  0.0025606722000512477,
#  0.014576617704778833,
#  -0.015307338941902737,
#  0.0081009208130353,
#  -0.007319805714354418,
#  -9.847603510018275e-05,
#  0.0008693056369740583,
#  0.001773257519429799,
#  -0.0013598648732215787,
#  -0.006935547164877969,
#  0.0062520714535321984,
#  -0.02660831280464207,
#  -0.014690006221588335,
#  0.01440023732668437,
#  -0.03184934518707932,
#  0.002308699399806907,
#  -0.001344116675069708,
#  -0.0003533522915082683,
#  0.012554537699943894,
#  -0.006973343026706963,
#  0.012598633027298141,
#  0.004236290448561252,
#  -0.034621042962968876,
#  0.00554969781127193,
#  -0.01720973189572544,
#  -0.01024268880020499,
#  0.009039518824557408,
#  -0.012756115940139368,
#  -0.005773323249483266,
#  -0.00193546491499965,
#  -0.01664279303696802,
#  -0.017310521481484438,
#  -0.014627012497658331,
#  -0.009152906410044388,
#  0.023269674307350045,
#  -0.01839400347479727,
#  -0.018935744471453683,
#  0.014186060155438392,
#  0.014387638395633865,
#  0.01356872743512399,
#  -0.0011897833785757925,
#  0.24814267491357134,
#  -0.013997080846293425,
#  -0.0011779721135465745,
#  0.012800211267493613,
#  0.01647901252124658,
#  0.010129301214718011,
#  0.016428616797044562,
#  -0.0009126134729299901,
#  -0.0332351940750241,
#  0.016101052040311602,
#  0.00904581829008266,
#  0.0029008351893428205,
#  -0.028573699482394778,
#  0.004715038186948925,
#  0.008145016140389545,
#  -0.03396591344950296,
#  -0.02172004304103879,
#  -0.00021102710378932042,
#  -0.008113519744085805,
#  -0.02985875878458056,
#  -0.00276697480656003,
#  -0.006595384408417027,
#  0.009883627647168292,
#  0.00298272637852606,
#  0.029581589752049622,
#  0.017474303859850916,
#  0.00823950626062329,
#  0.012756115940139368,
#  0.025587823603936723,
#  0.012006497237762226,
#  -0.015017570046998772,
#  -0.026658706666199048,
#  0.005061500874596379,
#  0.00782375084918184,
#  0.011250579069859835,
#  0.006721370459293253,
#  0.021039717528116904,
#  -0.012113585357723956,
#  0.010066307490788007,
#  0.0039055761918962975,
#  0.007735560660134607,
#  0.018331010682189786,
#  -0.019565676122818593,
#  -0.006141833600807844,
#  -0.016416017865994056,
#  0.01686957007058702,
#  ...]

# %% [markdown]
# ## Step 5 - Create tools for text data splitting
#
# Related docs:
# - [CharacterTextSplitter](https://python.langchain.com/en/latest/modules/indexes/text_splitters/examples/character_text_splitter.html);
# - [RecursiveCharacterTextSplitter](https://python.langchain.com/en/latest/modules/indexes/text_splitters/examples/recursive_text_splitter.html);
#
# Despite being more advance in terms of text chunk splitting the `RecursiveCharacterTextSplitter` shows not that impressive results in a realworld app.

# %%
chunk_size = 350
chunk_overlap = 50
length_function = len

recursive_text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap,
    length_function=length_function
)

character_text_splitter = CharacterTextSplitter(
    separator="\n\n",
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap,
    length_function=length_function,
)

# %% [markdown]
# ## Step 6 - Creating a context based text chunks
# Text chunks will be vectorised and put into a storage.
#
# To be maximum usable, the text must be split by its contextual parts. Those contextual parts must conform to the following requirements:
# - Be as small as possible;
# - Be as focused on the subject as possible;
#
# LLMs can be used to achieve this goal automatically:
# 1. Derive contextual parts from the text (ask LLM):
# 2. Split the overall document into chunks by their context (ask LLM);
# 3. Split the resulting text by a delimiter, usually it will be "\n\n" (can be done with some langchain text splitter or a customer one);
# 4. Repeat operation to achieve the desired granularity (the simplest check might be by length);
#
# Example of prompt to a generative OpenAI model to breakdown a text into small contextual peaces:
# ```
# Define the main components of the text below based on the context and semantics. Mandatory use of all of the above rules to perform the task:
# 1. Breakdown the original text into independent blocks by using the defined components;
# 2. Separate text blocks by an empty line between each other;
# 3. Define a general title, in a few words, for the text below based on its context;
# 4. Name each text block according to the general title of the original text and the main component that each block describes;
# 5. For block naming use only - the general title of the original text and the name of the component based on its context;
# 6. Do not use numbers in the block's name;
# 7. After the block's name use a new line;
#
# Text:
# {text}
# ```
#
# The expected output of the command is:
# ```
# General Title: {general_title_name}
#
# {general_title_name} - {block_name}
# {block_content}
# ```
#
# Content preprocessed with the above method is in `docs/preprocessed_with_gpt` directory.

# %% [markdown]
# ## Step 7 - Content loading and splitting by the Langchain tools
# The purpose is to get text chunks to further pass to the GPT as a context.
#
# Conclusion after experiments:
# Working with raw content without "context based splitting" produces not satisfactory results

# %%
loaded_pdf = PyPDFLoader(file_path="./docs/what_is_microservice_architecture.pdf")
recursively_split_pages = loaded_pdf.load_and_split(text_splitter=recursive_text_splitter)
character_split_pages = loaded_pdf.load_and_split(text_splitter=character_text_splitter)

[
    recursively_split_pages[0],
    "+++",
    recursively_split_pages[1],
    "+++",
    recursively_split_pages[2],
    "============",
    character_split_pages[0],
    "+++",
    character_split_pages[1],
    "+++",
    character_split_pages[2],
]
# Out:
# [Document(page_content='30/04/2023, 16:12 Microservice architecture style - Azure Architecture Center | Microsoft Learn\nhttps://learn.microsoft.com/en-us/azure/architecture/guide/architecture-styles/microservices 1/5Microservice architecture style\nAzure\nA microservices architecture consists of a collection of small, autonomous services. Each', metadata={'source': './docs/what_is_microservice_architecture.pdf', 'page': 0}),
#  '+++',
#  Document(page_content='service is self-contained and should implement a single business capability within a\nbounded context. A bounded context is a natural division within a business and provides\nan explicit boundary within which a domain model exists.\nMicroservices are small, independent, and loosely coupled. A single small team of', metadata={'source': './docs/what_is_microservice_architecture.pdf', 'page': 0}),
#  '+++',
#  Document(page_content='developers can write and maintain a service.\nEach service is a separate codebase, which can be managed by a small\ndevelopment team.\nServices can be deployed independently. A team can update an existing service\nwithout rebuilding and redeploying the entire application.', metadata={'source': './docs/what_is_microservice_architecture.pdf', 'page': 0}),
#  '============',
#  Document(page_content="30/04/2023, 16:12 Microservice architecture style - Azure Architecture Center | Microsoft Learn\nhttps://learn.microsoft.com/en-us/azure/architecture/guide/architecture-styles/microservices 1/5Microservice architecture style\nAzure\nA microservices architecture consists of a collection of small, autonomous services. Each\nservice is self-contained and should implement a single business capability within a\nbounded context. A bounded context is a natural division within a business and provides\nan explicit boundary within which a domain model exists.\nMicroservices are small, independent, and loosely coupled. A single small team of\ndevelopers can write and maintain a service.\nEach service is a separate codebase, which can be managed by a small\ndevelopment team.\nServices can be deployed independently. A team can update an existing service\nwithout rebuilding and redeploying the entire application.\nServices are responsible for persisting their own data or external state. This differs\nfrom the traditional model, where a separate data layer handles data persistence.\nServices communicate with each other by using well-defined APIs. Internal\nimplementation details of each service are hidden from other services.\nSupports polyglot programming. For example, services don't need to share the\nsame technology stack, libraries, or frameworks.What are microservices?", metadata={'source': './docs/what_is_microservice_architecture.pdf', 'page': 0}),
#  '+++',
#  Document(page_content="30/04/2023, 16:12 Microservice architecture style - Azure Architecture Center | Microsoft Learn\nhttps://learn.microsoft.com/en-us/azure/architecture/guide/architecture-styles/microservices 2/5Besides for the services themselves, some other components appear in a typical\nmicroservices architecture:\nManagement/orchestration. This component is responsible for placing services on\nnodes, identifying failures, rebalancing services across nodes, and so forth. Typically this\ncomponent is an off-the-shelf technology such as Kubernetes, rather than something\ncustom built.\nAPI Gateway. The API gateway is the entry point for clients. Instead of calling services\ndirectly, clients call the API gateway, which forwards the call to the appropriate services\non the back end.\nAdvantages of using an API gateway include:\nIt decouples clients from services. Services can be versioned or refactored without\nneeding to update all of the clients.\nServices can use messaging protocols that are not web friendly, such as AMQP.\nThe API Gateway can perform other cross-cutting functions such as authentication,\nlogging, SSL termination, and load balancing.\nOut-of-the-box policies, like for throttling, caching, transformation, or validation.\nAgility. Because microservices are deployed independently, it's easier to manage\nbug fixes and feature releases. You can update a service without redeploying the\nentire application, and roll back an update if something goes wrong. In many\ntraditional applications, if a bug is found in one part of the application, it can block\nthe entire release process. New features might be held up waiting for a bug fix to\nbe integrated, tested, and published.\nSmall, focused teams. A microservice should be small enough that a single feature\nteam can build, test, and deploy it. Small team sizes promote greater agility. Large\nteams tend be less productive, because communication is slower, management\noverhead goes up, and agility diminishes.\nSmall code base. In a monolithic application, there is a tendency over time for\ncode dependencies to become tangled. Adding a new feature requires touching\ncode in a lot of places. By not sharing code or data stores, a microservices\narchitecture minimizes dependencies, and that makes it easier to add new features.Benefits", metadata={'source': './docs/what_is_microservice_architecture.pdf', 'page': 1}),
#  '+++',
#  Document(page_content="30/04/2023, 16:12 Microservice architecture style - Azure Architecture Center | Microsoft Learn\nhttps://learn.microsoft.com/en-us/azure/architecture/guide/architecture-styles/microservices 3/5Mix of technologies. Teams can pick the technology that best fits their service,\nusing a mix of technology stacks as appropriate.\nFault isolation. If an individual microservice becomes unavailable, it won't disrupt\nthe entire application, as long as any upstream microservices are designed to\nhandle faults correctly. For example, you can implement the Circuit Breaker\npattern, or you can design your solution so that the microservices communicate\nwith each other using asynchronous messaging patterns.\nScalability. Services can be scaled independently, letting you scale out subsystems\nthat require more resources, without scaling out the entire application. Using an\norchestrator such as Kubernetes or Service Fabric, you can pack a higher density of\nservices onto a single host, which allows for more efficient utilization of resources.\nData isolation. It is much easier to perform schema updates, because only a single\nmicroservice is affected. In a monolithic application, schema updates can become\nvery challenging, because different parts of the application might all touch the\nsame data, making any alterations to the schema risky.\nThe benefits of microservices don't come for free. Here are some of the challenges to\nconsider before embarking on a microservices architecture.\nComplexity. A microservices application has more moving parts than the\nequivalent monolithic application. Each service is simpler, but the entire system as\na whole is more complex.\nDevelopment and testing. Writing a small service that relies on other dependent\nservices requires a different approach than a writing a traditional monolithic or\nlayered application. Existing tools are not always designed to work with service\ndependencies. Refactoring across service boundaries can be difficult. It is also\nchallenging to test service dependencies, especially when the application is\nevolving quickly.\nLack of governance. The decentralized approach to building microservices has\nadvantages, but it can also lead to problems. You might end up with so many\ndifferent languages and frameworks that the application becomes hard to\nmaintain. It might be useful to put some project-wide standards in place, without\noverly restricting teams' flexibility. This especially applies to cross-cutting\nfunctionality such as logging.Challenges", metadata={'source': './docs/what_is_microservice_architecture.pdf', 'page': 2})]

# %% [markdown]
# ## Step 8 - GPT pre-processed content loading and splitting by the Langchain tools
# The purpose is to get text chunks to further pass to the GPT as a context.
#
# Conclusion after experiments:
# Working with content that is "context based split" produces the required chunking result!
#
# Requirements:
#     - Contextual blocks are separated by a well identifiable delimiter (\n\n for example);
#
# Actual chunking of context grouped content can be conveniently done via `CharacterTextSplitter`.

# %%
loaded_pdf = TextLoader(file_path="./docs/preprocessed_with_gpt/what_is_microservice_architecture.txt")
recursively_split_pages = loaded_pdf.load_and_split(text_splitter=recursive_text_splitter)
character_split_pages = loaded_pdf.load_and_split(text_splitter=character_text_splitter)

[
    recursively_split_pages[0],
    "+++",
    recursively_split_pages[1],
    "+++",
    recursively_split_pages[2],
    "============",
    character_split_pages[0],
    "+++",
    character_split_pages[1],
    "+++",
    character_split_pages[2],
]
# Out:
# Created a chunk of size 627, which is longer than the specified 350
# Created a chunk of size 571, which is longer than the specified 350
# Created a chunk of size 365, which is longer than the specified 350
# Created a chunk of size 2223, which is longer than the specified 350
# Created a chunk of size 2272, which is longer than the specified 350
# Created a chunk of size 1494, which is longer than the specified 350
# [Document(page_content='1. What are microservices?', metadata={'source': './docs/preprocessed_with_gpt/what_is_microservice_architecture.txt'}),
#  '+++',
#  Document(page_content='Microservices are small, independent, and loosely coupled. A single small team of developers can write and maintain a service. Each service is a separate codebase, which can be managed by a small development team. Services can be deployed independently. A team can update an existing service without rebuilding and redeploying the entire application.', metadata={'source': './docs/preprocessed_with_gpt/what_is_microservice_architecture.txt'}),
#  '+++',
#  Document(page_content='rebuilding and redeploying the entire application. Services are responsible for persisting their own data or external state. Services communicate with each other by using well-defined APIs. Internal implementation details of each service are hidden from other services. Supports polyglot programming.', metadata={'source': './docs/preprocessed_with_gpt/what_is_microservice_architecture.txt'}),
#  '============',
#  Document(page_content='1. What are microservices?\nMicroservices are small, independent, and loosely coupled. A single small team of developers can write and maintain a service. Each service is a separate codebase, which can be managed by a small development team. Services can be deployed independently. A team can update an existing service without rebuilding and redeploying the entire application. Services are responsible for persisting their own data or external state. Services communicate with each other by using well-defined APIs. Internal implementation details of each service are hidden from other services. Supports polyglot programming.', metadata={'source': './docs/preprocessed_with_gpt/what_is_microservice_architecture.txt'}),
#  '+++',
#  Document(page_content='2. Management/orchestration\n This component is responsible for placing services on nodes, identifying failures, rebalancing services across nodes, and so forth. Typically this component is an off-the-shelf technology such as Kubernetes, rather than something custom built.', metadata={'source': './docs/preprocessed_with_gpt/what_is_microservice_architecture.txt'}),
#  '+++',
#  Document(page_content='3. API Gateway\nThe API gateway is the entry point for clients. Instead of calling services directly, clients call the API gateway, which forwards the call to the appropriate services on the back end. Advantages of using an API gateway include: It decouples clients from services. Services can use messaging protocols that are not web friendly, such as AMQP. The API Gateway can perform other cross-cutting functions such as authentication, logging, SSL termination, and load balancing. Out-of-the-box policies, like for throttling, caching, transformation, or validation.', metadata={'source': './docs/preprocessed_with_gpt/what_is_microservice_architecture.txt'})]
