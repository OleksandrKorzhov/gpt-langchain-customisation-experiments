# %% [markdown]
# ## Step 1 - Add your OpenAI API key.
# The key must be taken from a registered OpenAI account.
# Link to the keys sub-menu https://platform.openai.com/account/api-keys.

# %%
# %env OPENAI_API_KEY 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
# Out:
# env: OPENAI_API_KEY=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

# %% [markdown]
# ## Step 2 - Installing necessary libraries
# The libraries below are needed for:
# - Loading of text data from files and further preparation;
# - Creating embeddings via Langchain;
# - Prompting;

# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in ./venv/lib/python3.9/site-packages (0.0.142)
# Requirement already satisfied: requests<3,>=2 in ./venv/lib/python3.9/site-packages (from langchain) (2.28.2)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in ./venv/lib/python3.9/site-packages (from langchain) (0.5.7)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in ./venv/lib/python3.9/site-packages (from langchain) (4.0.2)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in ./venv/lib/python3.9/site-packages (from langchain) (2.8.4)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in ./venv/lib/python3.9/site-packages (from langchain) (1.2.4)
# Requirement already satisfied: pydantic<2,>=1 in ./venv/lib/python3.9/site-packages (from langchain) (1.10.7)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./venv/lib/python3.9/site-packages (from langchain) (3.8.4)
# Requirement already satisfied: SQLAlchemy<2,>=1 in ./venv/lib/python3.9/site-packages (from langchain) (1.4.47)
# Requirement already satisfied: gptcache>=0.1.7 in ./venv/lib/python3.9/site-packages (from langchain) (0.1.13)
# Requirement already satisfied: numpy<2,>=1 in ./venv/lib/python3.9/site-packages (from langchain) (1.24.2)
# Requirement already satisfied: PyYAML>=5.4.1 in ./venv/lib/python3.9/site-packages (from langchain) (6.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in ./venv/lib/python3.9/site-packages (from langchain) (8.2.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (3.1.0)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in ./venv/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in ./venv/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in ./venv/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (0.8.0)
# Requirement already satisfied: cachetools in ./venv/lib/python3.9/site-packages (from gptcache>=0.1.7->langchain) (5.3.0)
# Requirement already satisfied: openai in ./venv/lib/python3.9/site-packages (from gptcache>=0.1.7->langchain) (0.27.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in ./venv/lib/python3.9/site-packages (from pydantic<2,>=1->langchain) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2022.12.7)
# Requirement already satisfied: packaging>=17.0 in ./venv/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (23.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./venv/lib/python3.9/site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: tqdm in ./venv/lib/python3.9/site-packages (from openai->gptcache>=0.1.7->langchain) (4.65.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Step 3 - Libraries import
# Imported libraries will be used across the whole notebook

# %%
from langchain.embeddings import OpenAIEmbeddings
from langchain.document_loaders import TextLoader, PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter

# %% [markdown]
# ## Step 4 - Create tool for embedding generation
# The tool is provided by Langchain and simplified embeddings generation process while providing reasonable defaults.
#
# By default, OpenAIEmbeddings uses nearly optimal settings:
# Model: text-embedding-ada-002
# Max chunk length: 8191

# %%
embeddings = OpenAIEmbeddings()

# %%
query = "What am I doing here?"
query_embedding = embeddings.embed_query(query)

query_embedding
# Out:
# [-0.009068081133982732,
#  -0.03183904282672644,
#  0.01591952141336322,
#  -0.016360329425402716,
#  -0.034685410477182335,
#  0.004175095809067048,
#  -0.008400569650043679,
#  0.013702878696115835,
#  0.01699005808390151,
#  -0.01651146445245404,
#  0.023501444552416526,
#  -0.018828863233520593,
#  -0.0025803099791057707,
#  0.011605884852391604,
#  -0.0005061437829539754,
#  -0.0037279890296396737,
#  0.034030493268390034,
#  -0.014685254509304285,
#  -0.004798526398669893,
#  -0.012285990611477409,
#  -0.02120923432164348,
#  -0.015277198479717674,
#  0.017330111894766985,
#  -0.0029754643258148965,
#  0.008381677771662264,
#  0.017040437047133667,
#  0.009886727644973104,
#  -0.025277277394979272,
#  0.006933303999156955,
#  -0.018627351105882258,
#  0.017027841840664342,
#  0.007575626467141216,
#  -0.01518903669104526,
#  -0.017959838690620636,
#  -0.019962374073760364,
#  0.0009949700883352013,
#  0.01856437693618078,
#  -0.005466037882608945,
#  0.019471185235843565,
#  -0.011801100308117847,
#  0.010497563493767912,
#  -0.0023850942905488852,
#  -0.017304921481828335,
#  -0.005494375700181068,
#  -0.019194105594679572,
#  0.00887916328149115,
#  -0.005362133017172447,
#  -0.025969978360534402,
#  0.0015664481288044758,
#  0.002166263986845873,
#  0.023778524193580522,
#  -0.004291595415311585,
#  -0.042519226569751274,
#  -0.020856587166953825,
#  -0.010233078127750669,
#  0.005374727292319199,
#  0.004121568975540134,
#  0.03891718378403877,
#  -0.002485850820029338,
#  0.005579389152897437,
#  -0.011309912401523622,
#  0.024017821940626828,
#  0.00202772370060259,
#  -0.014685254509304285,
#  0.00773935576933929,
#  -0.00945851297675779,
#  0.004027109583633057,
#  0.00022276623296509993,
#  -0.008299813586224513,
#  -0.009414431616760296,
#  0.004678877990808025,
#  0.008734325857674492,
#  -0.016712978442737517,
#  -0.003112429978418871,
#  0.017695354255925964,
#  -0.023325120975071698,
#  -0.013715472971262589,
#  -0.0010319665282783775,
#  0.026776028733732877,
#  -0.0006958493015111747,
#  0.011819992186499262,
#  -0.02856445678276495,
#  -0.01534017078677401,
#  0.027582080969576497,
#  0.011202858734469794,
#  0.006530277881235145,
#  0.015995088926888883,
#  0.022330149955413926,
#  -0.004445878778318952,
#  -0.018803674683227085,
#  -0.003794110371143984,
#  0.011549209217247359,
#  0.024735711456475462,
#  0.02340068848859736,
#  0.0062909815311726945,
#  0.025516573279380436,
#  -0.004637945898089149,
#  0.033627469013113365,
#  0.017544219228874645,
#  -0.019206700801148897,
#  -0.0016483126634881918,
#  0.005714780637523388,
#  -0.01357693315068059,
#  -0.0042569604601660855,
#  -0.00982375533791677,
#  -0.0033784899780754207,
#  -0.027909539573972648,
#  -0.002758208190089907,
#  0.02337549807565871,
#  -0.011794802704883185,
#  -0.022884311100387057,
#  -0.0006738088543430712,
#  0.018388053358835952,
#  -0.026070734424353568,
#  -0.00241028353933432,
#  -0.016650004273036038,
#  0.014005147818895907,
#  0.031511582359685146,
#  -0.04476105783729216,
#  -0.02083139861666032,
#  0.02314879739772687,
#  0.019773455289946208,
#  0.005878509939721463,
#  0.01484898381150236,
#  0.03226725749494176,
#  -0.007027762925402746,
#  -0.02586922043407009,
#  -0.01568022366631691,
#  -0.011102102670650626,
#  -0.004260109261783417,
#  0.008677650222530246,
#  0.022103449277482087,
#  0.005107093124684627,
#  0.008589488433857833,
#  -0.007128519454883198,
#  0.00035481230504753484,
#  -0.010100834979080762,
#  0.01250639554881973,
#  -0.01078723834140123,
#  -0.027027919824603366,
#  0.0009886727179311819,
#  0.029471265082427735,
#  0.016385519838341366,
#  -0.019017782017334745,
#  -0.008923243710166071,
#  0.005381024895553863,
#  0.00916883812912447,
#  -0.019987562624053868,
#  -0.008526515195478923,
#  -0.02385409170710618,
#  -0.0010453482366601062,
#  0.016813734506556682,
#  -0.00020072575669316612,
#  0.007027762925402746,
#  0.017997622447383465,
#  0.006209116880073658,
#  -0.028740780360109776,
#  0.02612111152494058,
#  0.002356756472976762,
#  -0.010006375587173686,
#  -0.01609584499070805,
#  0.029143806478031584,
#  0.00040164831348741544,
#  -0.011435857946958866,
#  0.030529208409141844,
#  0.015050495939140691,
#  0.03047882944590969,
#  -0.00795976070668161,
#  -0.018249513538253954,
#  -0.007153708470837989,
#  -0.0050693093679217965,
#  0.02942088611919558,
#  -0.02534024970203561,
#  0.017695354255925964,
#  -0.012701611004545971,
#  0.007840111833158456,
#  -0.0064987917277069766,
#  -0.01809837851120263,
#  -0.0096852145860122,
#  -0.014584497514162546,
#  -0.03146120525909814,
#  -0.00308094359206006,
#  0.017267137725065506,
#  0.03387935824133871,
#  -0.009074378737217394,
#  0.0033721928405020443,
#  -0.0017742583253387576,
#  -0.013791040484788249,
#  0.0015215800340639362,
#  -0.017254544381241323,
#  -0.005443997668271484,
#  0.026045545874060064,
#  -0.026901975210490692,
#  -0.0004900069895724035,
#  -0.6730531438175569,
#  -0.022405717468939587,
#  0.041360527179217996,
#  -0.007575626467141216,
#  -0.0027251474029224305,
#  0.0074181943025165165,
#  0.004883539851386262,
#  0.01925707790173591,
#  -0.021146262014587143,
#  0.032619904649631416,
#  0.006719196665049297,
#  0.008885459953403242,
#  0.007751950044486043,
#  0.001766386670541394,
#  0.0036083406217778057,
#  -0.020327616434919343,
#  0.01031494231318842,
#  -0.00458756740051828,
#  -0.0059603745908205,
#  -0.008419461528425095,
#  -0.004121568975540134,
#  0.025844031883776583,
#  -0.00022729240245937055,
#  -0.004338825111265123,
#  0.01720416541800917,
#  0.009603350400574449,
#  -0.00040578091188335003,
#  -0.012317477696328148,
#  -0.008054219167266114,
#  0.02153669292603963,
#  -0.009861538163357027,
#  0.005107093124684627,
#  0.007109627576501782,
#  0.008551704677095002,
#  0.07012649608962128,
#  -0.015831358693368235,
#  0.00515747115659421,
#  0.031007800177944172,
#  -0.014584497514162546,
#  0.014571903239015792,
#  -0.013854013723167158,
#  -0.016234384811290047,
#  0.012153748394130075,
#  -0.014584497514162546,
#  0.006536575484469807,
#  -0.008589488433857833,
#  0.01624698001775937,
#  -0.012040397123841582,
#  0.026398193028749718,
#  0.00015605443294987924,
#  -0.007235573121937027,
#  -0.004134163716348172,
#  0.0005521926200933536,
#  0.014370390180054888,
#  -0.003561111158654911,
#  -0.020730642552841152,
#  0.013148718482465275,
#  0.008287219311077761,
#  0.023753335643287014,
#  0.010151213010990347,
#  -0.013992553543749155,
#  0.029647588659772562,
#  -0.019609726919070706,
#  -0.0015625122431981333,
#  -0.017556812572698824,
#  0.011662560487535849,
#  -0.03685167423119756,
#  0.025264682188509947,
#  0.006026495699494167,
#  -0.017304921481828335,
#  0.030806288050305837,
#  0.007128519454883198,
#  -0.03181385241378779,
#  0.025995166910827906,
#  0.012638638697489636,
#  0.02234274516188325,
#  0.006505088865280353,
#  -0.007613410223904046,
#  0.019559347955838552,
#  -0.009540377162195541,
#  0.0010917907322093114,
#  -0.007871598918009197,
#  -0.023136202191257546,
#  -0.007915679346684117,
#  0.01518903669104526,
#  -0.010573131007293571,
#  -0.030831476600599345,
#  0.008520218523566834,
#  0.012443423241763393,
#  0.003309220067784422,
#  0.01984902280347187,
#  0.02439565764560999,
#  -0.016461087351867028,
#  -0.030428450482677533,
#  -0.0013114083527319775,
#  0.003901164271028456,
#  -0.00894843319178215,
#  -0.010579428610528234,
#  0.004146757991494925,
#  0.008173868040789269,
#  -0.0007666936708184995,
#  -0.012632341094254974,
#  0.019080754324391082,
#  -0.0020261495326245674,
#  0.024257117825027992,
#  0.009275891796178298,
#  -0.016385519838341366,
#  0.02843851030600713,
#  0.00700887104702133,
#  -0.005494375700181068,
#  -0.002544100623151606,
#  -0.007808625679630288,
#  -0.00029144593212774634,
#  0.008633568862532753,
#  0.0007021465554998726,
#  -0.029194183578618596,
#  0.009445917770288463,
#  0.007298545894654649,
#  0.01207188327736975,
#  -0.007915679346684117,
#  0.009527782887048787,
#  0.011366588036667869,
#  0.016322545668639887,
#  -0.006618440135568844,
#  0.006561764500424599,
#  0.01903037722380407,
#  0.0006820739929272796,
#  0.015541683845734917,
#  -0.0319146103402521,
#  -0.016410708388634874,
#  0.006908114983202164,
#  -0.004584419064562235,
#  0.0162847637745222,
#  -0.0055290106553265665,
#  0.0075126536944235935,
#  0.017770919906806484,
#  -0.005928887971631046,
#  0.02259463625275374,
#  0.014597091789309298,
#  0.004140460853921548,
#  -0.021838962980142273,
#  -0.017997622447383465,
#  -0.010000078915261596,
#  0.0013665094706522363,
#  -0.008016436341825856,
#  -0.022733176073335738,
#  0.015226820447808091,
#  -0.008507623317097509,
#  0.0003306071440790073,
#  0.006687710045859843,
#  0.011234344887997962,
#  -0.006180779062501534,
#  -0.050831634431122534,
#  0.013513959912301683,
#  -0.0014672660001326888,
#  -0.015755791179842573,
#  0.02358960540976637,
#  -0.01467265930283496,
#  -0.012015207642225505,
#  -0.026448570129336726,
#  0.0022764662226863906,
#  0.02717905485165469,
#  -0.022053070314249933,
#  -0.024458629952666323,
#  -0.007248167862745066,
#  -0.012468611792056898,
#  -0.0032462472950668003,
#  0.01089429200845506,
#  -0.006180779062501534,
#  -0.017808703663569313,
#  -0.005160619958211541,
#  0.001926967287537459,
#  -0.011712938519445432,
#  -0.004099528295541387,
#  -0.017342705238591168,
#  0.005591983428044189,
#  -0.007292248757081273,
#  -0.013085745244086367,
#  -0.023249553461546037,
#  -0.01653665486539269,
#  -0.005094498383876589,
#  0.018035406204146297,
#  0.012040397123841582,
#  0.03395492575486437,
#  0.01846362087236161,
#  -0.0015703838979954968,
#  0.009364053584850712,
#  0.010573131007293571,
#  -0.0027991405156394256,
#  0.016435896938928378,
#  -0.003258841803044196,
#  0.012430828035294068,
#  -0.00048646479147971855,
#  0.027204243401948193,
#  0.005381024895553863,
#  -0.018488811285300263,
#  0.02312360698478822,
#  0.021045505950767977,
#  -0.009962295158498766,
#  0.015390549750006166,
#  0.015554278120881669,
#  0.019093349530860407,
#  0.0059981578819220446,
#  0.0006167397354119806,
#  -0.014105904814037645,
#  -0.03944615265342811,
#  -0.016108438334532228,
#  -0.015390549750006166,
#  -0.0058438745189146775,
#  0.013035367212176784,
#  0.010799833547870554,
#  -0.010346429398039161,
#  0.0073111406354626875,
#  -0.008822487646346905,
#  0.009370351188085374,
#  0.026196679038466238,
#  -0.01188296542487817,
#  0.013539149393917762,
#  -0.01382882424155108,
#  0.0063445083646996095,
#  0.009811160131447444,
#  0.014445957693580548,
#  -0.016889302020082344,
#  -0.01940821292878723,
#  0.002849518547549009,
#  0.02528987073880345,
#  0.002940829137838754,
#  0.03274584926374408,
#  0.004826864216242016,
#  -0.01969788777642055,
#  -0.03241839252199308,
#  -0.0096852145860122,
#  0.00884137952472832,
#  0.02532765449556628,
#  -0.02238052891864608,
#  -0.010333834191569836,
#  0.0004144396506697248,
#  0.004489959672655159,
#  -0.0013846141486293186,
#  -0.014118499089184399,
#  -0.016158817297764385,
#  0.014181471396240734,
#  0.02629743696493055,
#  -0.005680145682377889,
#  0.04967293504058926,
#  0.004297892552884961,
#  0.027808783510153482,
#  0.006574359241232637,
#  0.0018230621892703182,
#  0.02443344140237282,
#  -0.03347633398606205,
#  0.0023835201225708624,
#  -0.022317556611589746,
#  -0.006605845394760806,
#  -0.007670085393387005,
#  -0.023992631527688178,
#  0.006401183999843855,
#  -0.005012633732777551,
#  0.030000235814462217,
#  0.0117444246729736,
#  0.015655035116023407,
#  -0.0034383141820063545,
#  0.02942088611919558,
#  -0.016272168568052876,
#  0.011001345675508888,
#  -0.01056053673214682,
#  -0.023085823228025392,
#  -0.03418162829544136,
#  0.013400609573335763,
#  -0.0012130133080492018,
#  -0.0012287565012286073,
#  -0.006605845394760806,
#  0.006971087755919786,
#  -0.009401837341613543,
#  0.02560473599937542,
#  0.021146262014587143,
#  0.0160706545777694,
#  -0.004426986899937537,
#  0.015050495939140691,
#  0.008935838916635398,
#  -0.007563031726333176,
#  -0.024660143942949804,
#  0.020932154680479487,
#  -0.00044907469312671525,
#  0.0014712017693237099,
#  0.006268940851173949,
#  -0.01276458424292488,
#  -0.00022315981861535116,
#  0.00032922960157908565,
#  0.01584395389983756,
#  0.00254882359274696,
#  0.023274742011839544,
#  -0.01455930896386904,
#  -0.0027991405156394256,
#  0.008312407861371265,
#  0.006347657166316941,
#  0.045693054687248456,
#  0.012487503670438313,
#  0.018513999835593768,
#  -0.0015349617424456647,
#  0.0031722541823498047,
#  -0.009162540525889808,
#  0.008280921707843097,
#  -0.014483741450343379,
#  0.01711600456065933,
#  0.004896134126533014,
#  0.0269271637607842,
#  -0.02942088611919558,
#  0.0019175213483467513,
#  -0.025503979935556254,
#  1.9297714925270394e-05,
#  0.01166885715944794,
#  0.0064452648941800625,
#  -0.020579507525789832,
#  -0.01603287268365171,
#  -0.0016089547387473386,
#  -0.017292328138004156,
#  0.006316170547127487,
#  0.030579585509728856,
#  -0.007178897952454067,
#  -0.017909461590033624,
#  -0.0325695275490444,
#  -0.018501404629124443,
#  -0.011391777518283946,
#  0.08393013457484656,
#  0.02328733721830887,
#  -0.005654956200761811,
#  0.007581923604714592,
#  -0.019194105594679572,
#  -0.0028243295315942174,
#  -0.010686482277582064,
#  -0.030327694418858367,
#  0.014811200054739529,
#  0.007808625679630288,
#  -0.0134635818803921,
#  -0.009105864890745562,
#  -0.007241870725171689,
#  0.02094474988694881,
#  0.001039838183075741,
#  -0.0038476374375015416,
#  0.016007682270713062,
#  -0.005365281353128492,
#  -0.017594596329461653,
#  -0.02508835861116512,
#  -0.006631034410715597,
#  0.008576893227388506,
#  0.022367933712176755,
#  -0.001829359443259016,
#  -0.0033784899780754207,
#  0.023224364911252533,
#  -0.005979266003540629,
#  -0.01188296542487817,
#  0.009244405642650132,
#  -0.017418272752116826,
#  -0.008400569650043679,
#  0.01342579812362927,
#  -0.013639905457736927,
#  -0.00047150874049698506,
#  -0.017707947599750147,
#  0.01221672070118641,
#  -0.015554278120881669,
#  0.0180605947544398,
#  -0.0042097307642125475,
#  -0.003979880353340805,
#  0.004260109261783417,
#  0.007027762925402746,
#  -0.008167570437554606,
#  0.000440022354138174,
#  0.01892961929733976,
#  -0.022430907881878237,
#  -0.024458629952666323,
#  0.01716638166124634,
#  0.024156361761208826,
#  -0.00869654210091166,
#  0.018249513538253954,
#  0.007141114195691237,
#  -0.005349538276364408,
#  -0.018614755899412933,
#  0.017216760624478494,
#  0.01618400584805789,
#  0.0004994529287631112,
#  -0.01294720542350437,
#  -0.010566833404058909,
#  -0.016964869533608005,
#  -0.023199174498313883,
#  -0.01547871153867858,
#  0.006517683606088392,
#  0.0022323853283501833,
#  -0.018501404629124443,
#  -0.03146120525909814,
#  -0.026171490488172734,
#  0.015579467602497746,
#  -0.002610221964655916,
#  -0.004212879565829879,
#  0.027909539573972648,
#  -0.024496413709429156,
#  -0.02098253364371164,
#  -0.018362864808542444,
#  0.007814923282864952,
#  0.01847621607883094,
#  0.004146757991494925,
#  0.0007178898068869389,
#  -0.01925707790173591,
#  0.014924550393705447,
#  0.013513959912301683,
#  -0.055869456248532304,
#  -0.0013452562238884657,
#  -0.020126102444635866,
#  -0.01802281099767697,
#  0.011977423885462675,
#  0.020340209778743523,
#  0.01313612327599595,
#  -0.014030337300511985,
#  0.027204243401948193,
#  0.005692739957524642,
#  0.024257117825027992,
#  0.03272065885080543,
#  -0.02765764848310216,
#  0.017229353968302673,
#  0.0028510929483576745,
#  -0.003517030264318704,
#  -0.004291595415311585,
#  -0.00876581201120266,
#  0.00045655271861808197,
#  0.008898055159872567,
#  -0.03211612246789044,
#  0.0022811891922817442,
#  -0.007034060528637408,
#  0.0002640921150610395,
#  0.0025976274566785204,
#  0.02358960540976637,
#  0.0024701075104346104,
#  -0.017216760624478494,
#  -0.019571943162307877,
#  0.009760782099537861,
#  -0.03206574536730342,
#  0.021007722194005148,
#  -0.006794763712913672,
#  0.020856587166953825,
#  0.024118578004445994,
#  0.013098339519233119,
#  0.06352695062640157,
#  0.003400530425243524,
#  0.01357693315068059,
#  0.0009697809559650882,
#  -0.03141082815851113,
#  0.023438472245360192,
#  0.03294736139138242,
#  -0.0009327843996065904,
#  -0.0054628895466528994,
#  -0.005151174019020834,
#  -0.040932312511002676,
#  -0.0024386211240757997,
#  -0.020113509100811684,
#  -0.01695227432713868,
#  0.02370295668005486,
#  -0.005771455807006348,
#  -0.02282133879333072,
#  -0.01895480971027841,
#  -0.01192704585355309,
#  0.002761356758876595,
#  0.010384213154801992,
#  -0.0028621132883570478,
#  -0.018879242196752747,
#  -0.012890529788360125,
#  0.0017065625830257815,
#  -0.022166421584538423,
#  -0.00234888493459472,
#  -0.019496375648782215,
#  -0.03667535251649788,
#  0.005179511836592957,
#  0.00825573222622702,
#  0.00032922960157908565,
#  0.012959799698651122,
#  0.0012791347659688336,
#  0.004798526398669893,
#  -0.006083171334638413,
#  -0.005239335807693248,
#  -0.001268114542384782,
#  -0.029395697568902073,
#  -0.02255685249599091,
#  -0.007348924392225518,
#  0.031763475313200784,
#  0.034282386221905665,
#  0.018388053358835952,
#  0.006738088077769426,
#  0.032670281750218425,
#  0.013375420091719686,
#  -0.017619786742400306,
#  -0.01591952141336322,
#  -0.009911917126589183,
#  0.005642361925615059,
#  -0.014483741450343379,
#  0.02851407781953279,
#  -0.003331260514952526,
#  0.008564298952241754,
#  0.004524594627800658,
#  0.011649965281066524,
#  -0.013702878696115835,
#  0.01232377436824024,
#  -0.004848904430579476,
#  -0.0036177865609685134,
#  -0.03282141677726975,
#  -0.020037941587286022,
#  -0.017443461302410333,
#  -7.246790465764296e-05,
#  0.0015963601143546213,
#  -0.0026007760254652085,
#  0.0069584930151117465,
#  -0.022695392316572905,
#  0.002108014183723605,
#  0.016675194685974688,
#  -0.00972299834277503,
#  -0.014622281270925375,
#  0.020277237471687186,
#  -0.026448570129336726,
#  0.01928226831467456,
#  0.0009162540642305129,
#  0.03226725749494176,
#  -0.015617251359260577,
#  -0.0011138311793774149,
#  -0.004175095809067048,
#  0.0075189508319969695,
#  0.0016388668407128057,
#  0.005333795199600324,
#  0.005393619170700615,
#  -0.017342705238591168,
#  0.006379143319845109,
#  0.002322121517831263,
#  0.005957225789203169,
#  -0.010497563493767912,
#  -0.004848904430579476,
#  0.04188949977389762,
#  0.00616188718412012,
#  -0.004480513733464451,
#  -0.01580617014307473,
#  -0.009244405642650132,
#  -0.0423429011297613,
#  0.02345106558918437,
#  0.0010296050434807007,
#  -0.012512693152054392,
#  0.009118460097214887,
#  0.01981123904670904,
#  -0.02031502122845002,
#  -0.006939601136730331,
#  0.0033533009621206293,
#  0.02090696613018598,
#  0.021990098007193596,
#  0.006369697380654401,
#  0.01928226831467456,
#  -0.014874172361795864,
#  0.00528026836607341,
#  0.010138618735843593,
#  0.010163808217459672,
#  -0.008488731438716092,
#  0.03156195946027216,
#  0.007991246860209779,
#  -0.010503861097002574,
#  -0.012191532150892904,
#  -0.01196482961031592,
#  -0.006322467684700863,
#  0.004628499958898442,
#  -0.017695354255925964,
#  0.012046694727076245,
#  0.03788442900761817,
#  -0.016108438334532228,
#  0.004341973912882454,
#  -0.00568959115590731,
#  -0.021990098007193596,
#  0.024534197466191985,
#  0.003838191498310834,
#  -0.022179014928362602,
#  -0.004839458957050055,
#  -0.022279772854826914,
#  -0.023136202191257546,
#  0.008369083496515512,
#  0.0009304229148089136,
#  0.02385409170710618,
#  0.0014680530841217,
#  -0.014042931575658738,
#  0.001261817288396084,
#  -0.015314982236480505,
#  0.010170104889371761,
#  0.027103487338129027,
#  0.007808625679630288,
#  0.022216798685125435,
#  -0.009924511401735935,
#  0.005022079671968258,
#  -0.009049189255601315,
#  -0.005582537488853481,
#  -0.028236998178368798,
#  -0.016574438622155522,
#  -0.021272208491344962,
#  0.02279614838039207,
#  0.00526767362526537,
#  0.0015255158032549572,
#  0.0008595785455015886,
#  0.02612111152494058,
#  0.017355300445060493,
#  -0.0040491502636318035,
#  -0.00188918364718995,
#  0.008532812798713586,
#  -0.004726107686761563,
#  -0.014949739875321525,
#  0.010113429254227516,
#  0.003938947794960643,
#  -0.02884153642392894,
#  0.005771455807006348,
#  -0.03188941992731345,
#  -0.008866568075021826,
#  -0.017481245059173162,
#  0.006725493802622673,
#  -0.009036594980454563,
#  -0.02013869765110519,
#  -0.0068451422104845415,
#  -0.026423381579043222,
#  0.024899439827350968,
#  0.019685292569951225,
#  -0.017229353968302673,
#  -0.004578121461327573,
#  0.008224246072698851,
#  0.020151292857574516,
#  0.023085823228025392,
#  0.003199017599113262,
#  -0.005853320458105385,
#  0.0033753414092887327,
#  -0.017770919906806484,
#  0.007544139847951761,
#  -0.0005809239796599822,
#  -0.031511582359685146,
#  0.011775911757824341,
#  -0.00928218846809039,
#  -0.020604696076083336,
#  -0.030655153023254517,
#  0.004792229261096516,
#  0.018388053358835952,
#  -0.014836388605033033,
#  -0.02372814709299351,
#  0.01649887110862986,
#  0.006605845394760806,
#  0.01409330960756832,
#  -0.008646164069002078,
#  -0.027128677751067677,
#  0.0059981578819220446,
#  -0.009024000705307811,
#  0.007298545894654649,
#  -0.0002528750913759045,
#  -0.01071167082787557,
#  0.0035296247722960998,
#  0.012525287427201144,
#  0.020365400191682172,
#  -0.0030368626977238526,
#  0.0002072198253348624,
#  -0.021725611709853782,
#  0.020075725344048855,
#  0.015655035116023407,
#  -0.008098300527263607,
#  -0.03420681870838001,
#  -0.003028991159341811,
#  0.006769574696958881,
#  -0.0023205471170225974,
#  0.0013869756334269955,
#  -0.01156180349239411,
#  0.02614630193787923,
#  -0.02238052891864608,
#  0.009830052009828859,
#  -0.013639905457736927,
#  0.006876628364012709,
#  -0.01071167082787557,
#  0.010529049647296078,
#  -0.0009776524943471301,
#  0.009552971437342293,
#  -0.016486275902160535,
#  -0.011612182455626266,
#  -0.024420846195903494,
#  0.011391777518283946,
#  0.007449680921705971,
#  -0.015579467602497746,
#  -0.00880359576796549,
#  -0.014622281270925375,
#  -0.004389203143174706,
#  -0.04264517118386394,
#  0.020919559474010162,
#  -0.009590755194105124,
#  0.011958532007081258,
#  0.01581876348689891,
#  -0.010673887071112739,
#  0.03206574536730342,
#  -0.0018466770372470873,
#  -0.00773935576933929,
#  -0.008022733013737947,
#  -0.009105864890745562,
#  -0.0007533119624367709,
#  -0.021675232746621625,
#  0.003957839673342059,
#  0.005273970762838747,
#  -0.011618479127538356,
#  0.0005903698606430289,
#  0.007783436663675497,
#  -0.002468533342456588,
#  0.003243098493449469,
#  0.007997544463444441,
#  -0.024861656070588135,
#  0.010327537519657747,
#  0.0032777336814256114,
#  -0.0004943363589655909,
#  0.00953408049028345,
#  0.021247018078406312,
#  0.0026086477966778938,
#  -0.01870291861940792,
#  -0.01530238703001118,
#  0.0033942332876701477,
#  0.024823872313825306,
#  0.007216681243555611,
#  -0.0074118971649431405,
#  0.01188296542487817,
#  -0.028287377141600952,
#  0.0015507049356250702,
#  0.008325002136518019,
#  0.0026117963654645818,
#  0.014597091789309298,
#  -0.015289792754864428,
#  0.008117192405645023,
#  -0.0073111406354626875,
#  -0.00016481158633871085,
#  0.0008650886572936146,
#  0.0017506434773619883,
#  -0.0013602122166635382,
#  -0.0069647901526851234,
#  0.006256346576027196,
#  -0.026524137642862388,
#  -0.014634875546072129,
#  0.014357795904908134,
#  -0.03178866200084914,
#  0.0022308109275415177,
#  -0.0013594250162592054,
#  -0.0003705554982269404,
#  0.012512693152054392,
#  -0.006927006861583579,
#  0.012525287427201144,
#  0.004222325505020586,
#  -0.03466022378953397,
#  0.005573091549662774,
#  -0.017178976867715665,
#  -0.010176402492606424,
#  0.008973622673398227,
#  -0.01276458424292488,
#  -0.005758861531859595,
#  -0.0019127983787513975,
#  -0.016637410929211855,
#  -0.017304921481828335,
#  -0.014609686995778623,
#  -0.009225513764268715,
#  0.02328733721830887,
#  -0.018362864808542444,
#  -0.018879242196752747,
#  0.01419406660271006,
#  0.014483741450343379,
#  0.013513959912301683,
#  -0.001200418800071806,
#  0.24806240142355337,
#  -0.013916986030223493,
#  -0.0012240335316332535,
#  0.012758286639690218,
#  0.016486275902160535,
#  0.010144916339078255,
#  0.01639811318216555,
#  -0.0009438046813983029,
#  -0.0331740639319594,
#  0.01605806123394522,
#  0.009074378737217394,
#  0.002967592554602211,
#  -0.02851407781953279,
#  0.00473240482433494,
#  0.008148678559173192,
#  -0.03398011616780302,
#  -0.021775990673085936,
#  -0.00025110397777764685,
#  -0.00811089480241036,
#  -0.029949858713875205,
#  -0.002825903932402883,
#  -0.006517683606088392,
#  0.009880430041738442,
#  0.0029817614633882725,
#  0.029597209696540408,
#  0.017405679408292647,
#  0.008217948469464189,
#  0.012733098089396712,
#  0.025629924549668927,
#  0.012040397123841582,
#  -0.014974929356937602,
#  -0.02667527266991371,
#  0.004996890656013467,
#  0.007833815161246366,
#  0.011146183099325548,
#  0.006725493802622673,
#  0.021045505950767977,
#  -0.012109667034132581,
#  0.010044159343936517,
#  0.003857083143861606,
#  0.007707869150149836,
#  0.018299892501486108,
#  -0.01948378044231289,
#  -0.006215414017647034,
#  -0.016486275902160535,
#  0.016801139300087357,
#  ...]

# %% [markdown]
# ## Step 5 - Create tools for text data splitting
#
# Related docs:
# - [CharacterTextSplitter](https://python.langchain.com/en/latest/modules/indexes/text_splitters/examples/character_text_splitter.html);
# - [RecursiveCharacterTextSplitter](https://python.langchain.com/en/latest/modules/indexes/text_splitters/examples/recursive_text_splitter.html);
#
# Despite being more advance in terms of text chunk splitting the `RecursiveCharacterTextSplitter` shows not that impressive results in a realworld app.

# %%
chunk_size = 350
chunk_overlap = 50
length_function = len

recursive_text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap,
    length_function=length_function
)

character_text_splitter = CharacterTextSplitter(
    separator="\n\n",
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap,
    length_function=length_function,
)

# %% [markdown]
# ## Step 6 - Creating a context based text chunks
# Text chunks will be vectorised and put into a storage.
#
# To be maximum usable, the text must be split by its contextual parts. Those contextual parts must conform to the following requirements:
# - Be as small as possible;
# - Be as focused on the subject as possible;
#
# LLMs can be used to achieve this goal automatically:
# 1. Derive contextual parts from the text (ask LLM):
# 2. Split the overall document into chunks by their context (ask LLM);
# 3. Split the resulting text by a delimiter, usually it will be "\n\n" (can be done with some langchain text splitter or a customer one);
# 4. Repeat operation to achieve the desired granularity (the simplest check might be by length);
#
# Example of prompt to a generative OpenAI model to breakdown a text into small contextual peaces:
# ```
# Define the main components of the text below based on the context and semantics. Mandatory use of all of the above rules to perform the task:
# 1. Breakdown the original text into independent blocks by using the defined components;
# 2. Separate text blocks by an empty line between each other;
# 3. Define a general title, in a few words, for the text below based on its context;
# 4. Name each text block according to the general title of the original text and the main component that each block describes;
# 5. For block naming use only - the general title of the original text and the name of the component based on its context;
# 6. Do not use numbers in the block's name;
# 7. After the block's name use a new line;
#
# Text:
# {text}
# ```
#
# The expected output of the command is:
# ```
# General Title: {general_title_name}
#
# {general_title_name} - {block_name}
# {block_content}
# ```
#
# Content preprocessed with the above method is in `docs/preprocessed_with_gpt` directory.

# %% [markdown]
# ## Step 7 - Content loading and splitting by the Langchain tools
# The purpose is to get text chunks to further pass to the GPT as a context.
#
# Conclusion after experiments:
# Working with raw content without "context based splitting" produces not satisfactory results

# %%
loaded_pdf = PyPDFLoader(file_path="./docs/what_is_microservice_architecture.pdf")
recursively_split_pages = loaded_pdf.load_and_split(text_splitter=recursive_text_splitter)
character_split_pages = loaded_pdf.load_and_split(text_splitter=character_text_splitter)

[
    recursively_split_pages[0],
    "+++",
    recursively_split_pages[1],
    "+++",
    recursively_split_pages[2],
    "============",
    character_split_pages[0],
    "+++",
    character_split_pages[1],
    "+++",
    character_split_pages[2],
]
# Out:
# [Document(page_content='30/04/2023, 16:12 Microservice architecture style - Azure Architecture Center | Microsoft Learn\nhttps://learn.microsoft.com/en-us/azure/architecture/guide/architecture-styles/microservices 1/5Microservice architecture style\nAzure\nA microservices architecture consists of a collection of small, autonomous services. Each', metadata={'source': './docs/what_is_microservice_architecture.pdf', 'page': 0}),
#  '+++',
#  Document(page_content='service is self-contained and should implement a single business capability within a\nbounded context. A bounded context is a natural division within a business and provides\nan explicit boundary within which a domain model exists.\nMicroservices are small, independent, and loosely coupled. A single small team of', metadata={'source': './docs/what_is_microservice_architecture.pdf', 'page': 0}),
#  '+++',
#  Document(page_content='developers can write and maintain a service.\nEach service is a separate codebase, which can be managed by a small\ndevelopment team.\nServices can be deployed independently. A team can update an existing service\nwithout rebuilding and redeploying the entire application.', metadata={'source': './docs/what_is_microservice_architecture.pdf', 'page': 0}),
#  '============',
#  Document(page_content="30/04/2023, 16:12 Microservice architecture style - Azure Architecture Center | Microsoft Learn\nhttps://learn.microsoft.com/en-us/azure/architecture/guide/architecture-styles/microservices 1/5Microservice architecture style\nAzure\nA microservices architecture consists of a collection of small, autonomous services. Each\nservice is self-contained and should implement a single business capability within a\nbounded context. A bounded context is a natural division within a business and provides\nan explicit boundary within which a domain model exists.\nMicroservices are small, independent, and loosely coupled. A single small team of\ndevelopers can write and maintain a service.\nEach service is a separate codebase, which can be managed by a small\ndevelopment team.\nServices can be deployed independently. A team can update an existing service\nwithout rebuilding and redeploying the entire application.\nServices are responsible for persisting their own data or external state. This differs\nfrom the traditional model, where a separate data layer handles data persistence.\nServices communicate with each other by using well-defined APIs. Internal\nimplementation details of each service are hidden from other services.\nSupports polyglot programming. For example, services don't need to share the\nsame technology stack, libraries, or frameworks.What are microservices?", metadata={'source': './docs/what_is_microservice_architecture.pdf', 'page': 0}),
#  '+++',
#  Document(page_content="30/04/2023, 16:12 Microservice architecture style - Azure Architecture Center | Microsoft Learn\nhttps://learn.microsoft.com/en-us/azure/architecture/guide/architecture-styles/microservices 2/5Besides for the services themselves, some other components appear in a typical\nmicroservices architecture:\nManagement/orchestration. This component is responsible for placing services on\nnodes, identifying failures, rebalancing services across nodes, and so forth. Typically this\ncomponent is an off-the-shelf technology such as Kubernetes, rather than something\ncustom built.\nAPI Gateway. The API gateway is the entry point for clients. Instead of calling services\ndirectly, clients call the API gateway, which forwards the call to the appropriate services\non the back end.\nAdvantages of using an API gateway include:\nIt decouples clients from services. Services can be versioned or refactored without\nneeding to update all of the clients.\nServices can use messaging protocols that are not web friendly, such as AMQP.\nThe API Gateway can perform other cross-cutting functions such as authentication,\nlogging, SSL termination, and load balancing.\nOut-of-the-box policies, like for throttling, caching, transformation, or validation.\nAgility. Because microservices are deployed independently, it's easier to manage\nbug fixes and feature releases. You can update a service without redeploying the\nentire application, and roll back an update if something goes wrong. In many\ntraditional applications, if a bug is found in one part of the application, it can block\nthe entire release process. New features might be held up waiting for a bug fix to\nbe integrated, tested, and published.\nSmall, focused teams. A microservice should be small enough that a single feature\nteam can build, test, and deploy it. Small team sizes promote greater agility. Large\nteams tend be less productive, because communication is slower, management\noverhead goes up, and agility diminishes.\nSmall code base. In a monolithic application, there is a tendency over time for\ncode dependencies to become tangled. Adding a new feature requires touching\ncode in a lot of places. By not sharing code or data stores, a microservices\narchitecture minimizes dependencies, and that makes it easier to add new features.Benefits", metadata={'source': './docs/what_is_microservice_architecture.pdf', 'page': 1}),
#  '+++',
#  Document(page_content="30/04/2023, 16:12 Microservice architecture style - Azure Architecture Center | Microsoft Learn\nhttps://learn.microsoft.com/en-us/azure/architecture/guide/architecture-styles/microservices 3/5Mix of technologies. Teams can pick the technology that best fits their service,\nusing a mix of technology stacks as appropriate.\nFault isolation. If an individual microservice becomes unavailable, it won't disrupt\nthe entire application, as long as any upstream microservices are designed to\nhandle faults correctly. For example, you can implement the Circuit Breaker\npattern, or you can design your solution so that the microservices communicate\nwith each other using asynchronous messaging patterns.\nScalability. Services can be scaled independently, letting you scale out subsystems\nthat require more resources, without scaling out the entire application. Using an\norchestrator such as Kubernetes or Service Fabric, you can pack a higher density of\nservices onto a single host, which allows for more efficient utilization of resources.\nData isolation. It is much easier to perform schema updates, because only a single\nmicroservice is affected. In a monolithic application, schema updates can become\nvery challenging, because different parts of the application might all touch the\nsame data, making any alterations to the schema risky.\nThe benefits of microservices don't come for free. Here are some of the challenges to\nconsider before embarking on a microservices architecture.\nComplexity. A microservices application has more moving parts than the\nequivalent monolithic application. Each service is simpler, but the entire system as\na whole is more complex.\nDevelopment and testing. Writing a small service that relies on other dependent\nservices requires a different approach than a writing a traditional monolithic or\nlayered application. Existing tools are not always designed to work with service\ndependencies. Refactoring across service boundaries can be difficult. It is also\nchallenging to test service dependencies, especially when the application is\nevolving quickly.\nLack of governance. The decentralized approach to building microservices has\nadvantages, but it can also lead to problems. You might end up with so many\ndifferent languages and frameworks that the application becomes hard to\nmaintain. It might be useful to put some project-wide standards in place, without\noverly restricting teams' flexibility. This especially applies to cross-cutting\nfunctionality such as logging.Challenges", metadata={'source': './docs/what_is_microservice_architecture.pdf', 'page': 2})]

# %% [markdown]
# ## Step 8 - GPT pre-processed content loading and splitting by the Langchain tools
# The purpose is to get text chunks to further pass to the GPT as a context.
#
# Conclusion after experiments:
# Working with content that is "context based split" produces the required chunking result!
#
# Requirements:
#     - Contextual blocks are separated by a well identifiable delimiter (\n\n for example);
#
# Actual chunking of context grouped content can be conveniently done via `CharacterTextSplitter`.

# %%
loaded_pdf = TextLoader(file_path="./docs/preprocessed_with_gpt/what_is_microservice_architecture.txt")
recursively_split_pages = loaded_pdf.load_and_split(text_splitter=recursive_text_splitter)
character_split_pages = loaded_pdf.load_and_split(text_splitter=character_text_splitter)

[
    recursively_split_pages[0],
    "+++",
    recursively_split_pages[1],
    "+++",
    recursively_split_pages[2],
    "============",
    character_split_pages[0],
    "+++",
    character_split_pages[1],
    "+++",
    character_split_pages[2],
]
# Out:
# Created a chunk of size 409, which is longer than the specified 350
# Created a chunk of size 848, which is longer than the specified 350
# Created a chunk of size 1077, which is longer than the specified 350
# Created a chunk of size 2231, which is longer than the specified 350
# Created a chunk of size 2425, which is longer than the specified 350
# Created a chunk of size 1525, which is longer than the specified 350
# [Document(page_content='General title: Microservice Architecture Style\nMicroservice Architecture Style - Overview', metadata={'source': './docs/preprocessed_with_gpt/what_is_microservice_architecture.txt'}),
#  '+++',
#  Document(page_content='A microservices architecture consists of a collection of small, autonomous services. Each service is self-contained and should implement a single business capability within a bounded context. A bounded context is a natural division within a business and provides an explicit boundary within which a domain model exists.', metadata={'source': './docs/preprocessed_with_gpt/what_is_microservice_architecture.txt'}),
#  '+++',
#  Document(page_content='Microservice Architecture Style - What are Microservices?', metadata={'source': './docs/preprocessed_with_gpt/what_is_microservice_architecture.txt'}),
#  '============',
#  Document(page_content='General title: Microservice Architecture Style\nMicroservice Architecture Style - Overview\nA microservices architecture consists of a collection of small, autonomous services. Each service is self-contained and should implement a single business capability within a bounded context. A bounded context is a natural division within a business and provides an explicit boundary within which a domain model exists.', metadata={'source': './docs/preprocessed_with_gpt/what_is_microservice_architecture.txt'}),
#  '+++',
#  Document(page_content="Microservice Architecture Style - What are Microservices?\nMicroservices are small, independent, and loosely coupled. A single small team of developers can write and maintain a service. Each service is a separate codebase, which can be managed by a small development team. Services can be deployed independently. A team can update an existing service without rebuilding and redeploying the entire application. Services are responsible for persisting their own data or external state. This differs from the traditional model, where a separate data layer handles data persistence. Services communicate with each other by using well-defined APIs. Internal implementation details of each service are hidden from other services. Supports polyglot programming. For example, services don't need to share the same technology stack, libraries, or frameworks.", metadata={'source': './docs/preprocessed_with_gpt/what_is_microservice_architecture.txt'}),
#  '+++',
#  Document(page_content='Microservice Architecture Style - Components\nBesides for the services themselves, some other components appear in a typical microservices architecture: Management/orchestration. This component is responsible for placing services on nodes, identifying failures, rebalancing services across nodes, and so forth. Typically this component is an off-the-shelf technology such as Kubernetes, rather than something custom built. API Gateway. The API gateway is the entry point for clients. Instead of calling services directly, clients call the API gateway, which forwards the call to the appropriate services on the back end. Advantages of using an API gateway include: It decouples clients from services. Services can be versioned or refactored without needing to update all of the clients. Services can use messaging protocols that are not web friendly, such as AMQP. The API Gateway can perform other cross-cutting functions such as authentication, logging, SSL termination, and load balancing. Out-of-the-box policies, like for throttling, caching, transformation, or validation.', metadata={'source': './docs/preprocessed_with_gpt/what_is_microservice_architecture.txt'})]
